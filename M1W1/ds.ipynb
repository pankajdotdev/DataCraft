# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import pandas as pd

# %%
df= pd.read_csv("./war_economic_impact_dataset.csv")
df.head()
# Out:
#       Conflict_Name                  Conflict_Type       Region  Start_Year  \
# 0      WWII (Japan)                      World War    East Asia        1939
# 1  Israel-Hamas War                 Asymmetric War  Middle East        2023
# 2  Syrian Civil War                      Civil War  Middle East        2011
# 3    WWII (Germany)                      World War       Europe        1939
# 4   Afghanistan War  Interstate/Counter-insurgency   South Asia        2001
#
#    End_Year    Status   Primary_Country  Pre_War_Unemployment_%  \
# 0      1945  Resolved             Japan                    7.49
# 1      2026   Ongoing  Palestine (Gaza)                    8.18
# 2      2026   Ongoing             Syria                   12.70
# 3      1945  Resolved           Germany                   14.06
# 4      2021  Resolved       Afghanistan                    5.38
#
#    During_War_Unemployment_%  Unemployment_Spike_Percentage_Points  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Conflict_Name', 'Conflict_Type', 'Region', 'Start_Year', 'End_Year',
#        'Status', 'Primary_Country', 'Pre_War_Unemployment_%',
#        'During_War_Unemployment_%', 'Unemployment_Spike_Percentage_Points',
#        'Most_Affected_Sector', 'Youth_Unemployment_Change_%',
#        'Pre_War_Poverty_Rate_%', 'During_War_Poverty_Rate_%',
#        'Extreme_Poverty_Rate_%', 'Food_Insecurity_Rate_%',
#        'Households_Fallen_Into_Poverty_Estimate', 'GDP_Change_%',
#        'Inflation_Rate_%', 'Currency_Devaluation_%', 'Cost_of_War_USD',
#        'Estimated_Reconstruction_Cost_USD', 'Informal_Economy_Size_Pre_War_%',
#        'Informal_Economy_Size_During_War_%', 'Black_Market_Activity_Level',
#        'Primary_Black_Market_Goods', 'Currency_Black_Market_Rate_Gap_%',
#        'War_Profiteering_Documented'],
#       dtype='object')

# %%
inflation_above80 = df[df["Inflation_Rate_%"] > 80]
inflation_above80

# %%
df= df.fillna(0)
df.head()
# Out:
#       Conflict_Name                  Conflict_Type       Region  Start_Year  \
# 0      WWII (Japan)                      World War    East Asia        1939
# 1  Israel-Hamas War                 Asymmetric War  Middle East        2023
# 2  Syrian Civil War                      Civil War  Middle East        2011
# 3    WWII (Germany)                      World War       Europe        1939
# 4   Afghanistan War  Interstate/Counter-insurgency   South Asia        2001
#
#    End_Year    Status   Primary_Country  Pre_War_Unemployment_%  \
# 0      1945  Resolved             Japan                    7.49
# 1      2026   Ongoing  Palestine (Gaza)                    8.18
# 2      2026   Ongoing             Syria                   12.70
# 3      1945  Resolved           Germany                   14.06
# 4      2021  Resolved       Afghanistan                    5.38
#
#    During_War_Unemployment_%  Unemployment_Spike_Percentage_Points  ...  \
# ...

# %%
top_3_reconstruction_costs = df.sort_values(by="Estimated_Reconstruction_Cost_USD", ascending=False).head(3)
top_3_reconstruction_costs
# Out:
#           Conflict_Name   Conflict_Type       Region  Start_Year  End_Year  \
# 28592    WWII (Germany)       World War       Europe        1939      1945
# 16603  Israel-Hamas War  Asymmetric War  Middle East        2023      2026
# 8356   Syrian Civil War       Civil War  Middle East        2011      2026
#
#          Status Primary_Country  Pre_War_Unemployment_%  \
# 28592  Resolved         Germany                    9.33
# 16603   Ongoing          Israel                    8.72
# 8356    Ongoing           Syria                   10.75
#
#        During_War_Unemployment_%  Unemployment_Spike_Percentage_Points  ...  \
# 28592                      18.52                                  9.19  ...
# 16603                      35.76                                 27.03  ...
# 8356                       62.73                                 51.97  ...
#
#       Inflation_Rate_%  Currency_Devaluation_%  Cost_of_War_USD  \
# ...

# %%
inflation_avg = df["Inflation_Rate_%"].mean()
float_inflation_avg = float(inflation_avg)
float_inflation_avg
# Out:
# 69.9459648

# %%
df['duration_years'] = df["End_Year"] - df["Start_Year"]
df.head()
# Out:
#       Conflict_Name                  Conflict_Type       Region  Start_Year  \
# 0      WWII (Japan)                      World War    East Asia        1939
# 1  Israel-Hamas War                 Asymmetric War  Middle East        2023
# 2  Syrian Civil War                      Civil War  Middle East        2011
# 3    WWII (Germany)                      World War       Europe        1939
# 4   Afghanistan War  Interstate/Counter-insurgency   South Asia        2001
#
#    End_Year    Status   Primary_Country  Pre_War_Unemployment_%  \
# 0      1945  Resolved             Japan                    7.49
# 1      2026   Ongoing  Palestine (Gaza)                    8.18
# 2      2026   Ongoing             Syria                   12.70
# 3      1945  Resolved           Germany                   14.06
# 4      2021  Resolved       Afghanistan                    5.38
#
#    During_War_Unemployment_%  Unemployment_Spike_Percentage_Points  ...  \
# ...

# %%
avg_duration_years = df["duration_years"].mean()
avg_duration_years
# Out:
# np.float64(9.6386)

# %%
ongoing_wars = df[df["End_Year"] == 2026]
ongoing_wars.head()
# Out:
#          Conflict_Name   Conflict_Type       Region  Start_Year  End_Year  \
# 1     Israel-Hamas War  Asymmetric War  Middle East        2023      2026
# 2     Syrian Civil War       Civil War  Middle East        2011      2026
# 7     Israel-Hamas War  Asymmetric War  Middle East        2023      2026
# 9     Syrian Civil War       Civil War  Middle East        2011      2026
# 12  Russia-Ukraine War  Interstate War       Europe        2022      2026
#
#      Status   Primary_Country  Pre_War_Unemployment_%  \
# 1   Ongoing  Palestine (Gaza)                    8.18
# 2   Ongoing             Syria                   12.70
# 7   Ongoing  Palestine (Gaza)                    8.13
# 9   Ongoing             Syria                    7.41
# 12  Ongoing           Ukraine                    9.58
#
#     During_War_Unemployment_%  Unemployment_Spike_Percentage_Points  ...  \
# 1                       23.00                                 14.82  ...
# ...

# %%
df1 = df.groupby("Region")["duration_years"].mean()
df1
# Out:
# Region
# Africa         16.077212
# East Asia       6.000000
# Europe          5.006200
# Middle East     7.563249
# South Asia     20.000000
# Name: duration_years, dtype: float64
